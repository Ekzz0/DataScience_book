# %%
# %reset

# %%
import pandas as pd
import seaborn as sns
import missingno as msno

# %% [markdown]
# <big>Загрузка датасетов</big>

# %%
df_battles = pd.read_csv("../datasets/game_of_thrones/battles.csv")
df_battles
print(list(df_battles.columns))


# df_battles = pd.read_csv("../datasets/game_of_thrones/character-deaths.csv")
# print(list(df_battles.columns))
#
# df_battles = pd.read_csv("../datasets/game_of_thrones/character-predictions.csv")
# print(list(df_battles.columns))
# Out:
# ['name', 'year', 'battle_number', 'attacker_king', 'defender_king', 'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1', 'defender_2', 'defender_3', 'defender_4', 'attacker_outcome', 'battle_type', 'major_death', 'major_capture', 'attacker_size', 'defender_size', 'attacker_commander', 'defender_commander', 'summer', 'location', 'region', 'note']

# %%
df_battles
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %% [markdown]
# <big>Удалим пропуски</big>

# %%
msno.bar(df_battles)
# Out:
# <Axes: >

# %%
columns_to_delete = ["attacker_2", "attacker_3", "attacker_4", "defender_2", "defender_3", "defender_4", "note"]

# %%
df_battles.drop(columns=columns_to_delete, inplace=True)

# %%
df_battles
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
# for col in list(df_battles.columns):
#     print(f"{col}: {df_battles[col].unique()} \nКол-во: {len(df_battles[col].unique())}\n")
